# %%
# !pip install torch==1.3.1+cpu -f https://download.pytorch.org/whl/torch_stable.html 
# !pip install inltk 
# !pip install tornado==4.5.3      
from inltk.inltk import setup 
setup('hi') 
from inltk.inltk import tokenize 
hindi_text = """प्राकृ तिक भाषा सीखना बहुि तिलचस्प है।""" 
# tokenize(input text, language code) 
tokenize(hindi_text, "hi")
# Out:
# Collecting inltk
#   Obtaining dependency information for inltk from https://files.pythonhosted.org/packages/8d/cc/942b7e86043dc9caa3ea967665b30b84527f2a163aaf3f7d14d9afcd7d1a/inltk-0.9-py3-none-any.whl.metadata
#   Using cached inltk-0.9-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: aiohttp>=3.5.4 in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (3.8.5)
# Requirement already satisfied: async-timeout>=3.0.1 in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (4.0.2)
# Requirement already satisfied: Pillow in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (9.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (4.12.2)
# Requirement already satisfied: bottleneck in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (1.3.5)
# Requirement already satisfied: fastprogress>=0.1.19 in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (1.0.3)
# Requirement already satisfied: matplotlib in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (3.7.2)
# Requirement already satisfied: numexpr in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (2.8.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (1.24.3)
# Requirement already satisfied: nvidia-ml-py3 in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (7.352.0)
# Requirement already satisfied: packaging in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (23.1)
# Requirement already satisfied: pandas in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (2.0.3)
# Requirement already satisfied: pyyaml in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (6.0)
# Requirement already satisfied: requests in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (2.31.0)
# Requirement already satisfied: scipy in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (1.11.1)
# Requirement already satisfied: spacy>=2.0.18 in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (3.7.5)
# Requirement already satisfied: typing in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (3.7.4.3)
# Collecting fastai==1.0.57 (from inltk)
#   Obtaining dependency information for fastai==1.0.57 from https://files.pythonhosted.org/packages/c1/e2/42342ded0385d694e3250e74f43f0dc9a3ff3d5c2241a2ddd98236b5f9de/fastai-1.0.57-py3-none-any.whl.metadata
#   Using cached fastai-1.0.57-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: sentencepiece in c:\users\kargu\anaconda3\lib\site-packages (from inltk) (0.2.0)
# Requirement already satisfied: torch>=1.0.0 in c:\users\kargu\anaconda3\lib\site-packages (from fastai==1.0.57->inltk) (2.4.0)
# Collecting torchvision (from fastai==1.0.57->inltk)
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/6a/38/e8257ad99ea2ec30bbb4e6d9d81f3fe796e39046bb060d80569cbf6d83e5/torchvision-0.19.0-1-cp311-cp311-win_amd64.whl.metadata
#   Using cached torchvision-0.19.0-1-cp311-cp311-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kargu\anaconda3\lib\site-packages (from aiohttp>=3.5.4->inltk) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\kargu\anaconda3\lib\site-packages (from aiohttp>=3.5.4->inltk) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kargu\anaconda3\lib\site-packages (from aiohttp>=3.5.4->inltk) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kargu\anaconda3\lib\site-packages (from aiohttp>=3.5.4->inltk) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kargu\anaconda3\lib\site-packages (from aiohttp>=3.5.4->inltk) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kargu\anaconda3\lib\site-packages (from aiohttp>=3.5.4->inltk) (1.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\kargu\anaconda3\lib\site-packages (from spacy>=2.0.18->inltk) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kargu\anaconda3\lib\site-packages (from requests->inltk) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kargu\anaconda3\lib\site-packages (from requests->inltk) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kargu\anaconda3\lib\site-packages (from requests->inltk) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kargu\anaconda3\lib\site-packages (from beautifulsoup4->inltk) (2.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kargu\anaconda3\lib\site-packages (from matplotlib->inltk) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kargu\anaconda3\lib\site-packages (from matplotlib->inltk) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kargu\anaconda3\lib\site-packages (from matplotlib->inltk) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kargu\anaconda3\lib\site-packages (from matplotlib->inltk) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\kargu\anaconda3\lib\site-packages (from matplotlib->inltk) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kargu\anaconda3\lib\site-packages (from matplotlib->inltk) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kargu\anaconda3\lib\site-packages (from pandas->inltk) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kargu\anaconda3\lib\site-packages (from pandas->inltk) (2023.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\kargu\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=2.0.18->inltk) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\kargu\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->inltk) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\kargu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->inltk) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\kargu\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.18->inltk) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\kargu\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.18->inltk) (0.1.5)
# Requirement already satisfied: filelock in c:\users\kargu\anaconda3\lib\site-packages (from torch>=1.0.0->fastai==1.0.57->inltk) (3.9.0)
# Requirement already satisfied: sympy in c:\users\kargu\anaconda3\lib\site-packages (from torch>=1.0.0->fastai==1.0.57->inltk) (1.11.1)
# Requirement already satisfied: networkx in c:\users\kargu\anaconda3\lib\site-packages (from torch>=1.0.0->fastai==1.0.57->inltk) (3.1)
# Requirement already satisfied: fsspec in c:\users\kargu\anaconda3\lib\site-packages (from torch>=1.0.0->fastai==1.0.57->inltk) (2023.4.0)
# Requirement already satisfied: colorama in c:\users\kargu\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy>=2.0.18->inltk) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\kargu\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.18->inltk) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\kargu\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.18->inltk) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\kargu\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.18->inltk) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\kargu\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.18->inltk) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\kargu\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.18->inltk) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kargu\anaconda3\lib\site-packages (from jinja2->spacy>=2.0.18->inltk) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\kargu\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=2.0.18->inltk) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kargu\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.18->inltk) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kargu\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.18->inltk) (2.15.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\kargu\anaconda3\lib\site-packages (from sympy->torch>=1.0.0->fastai==1.0.57->inltk) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kargu\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.18->inltk) (0.1.0)
# Using cached inltk-0.9-py3-none-any.whl (13 kB)
# Using cached fastai-1.0.57-py3-none-any.whl (233 kB)
# Using cached torchvision-0.19.0-1-cp311-cp311-win_amd64.whl (1.3 MB)
# Installing collected packages: torchvision, fastai, inltk
# Successfully installed fastai-1.0.57 inltk-0.9 torchvision-0.19.0
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 get_ipython().system('pip install inltk')
#       3 # !pip install tornado==4.5.3
# ----> 4 from inltk.inltk import setup
#       5 setup('hi')
#       6 from inltk.inltk import tokenize
#
# File ~\anaconda3\Lib\site-packages\inltk\inltk.py:8
#       5 from math import ceil
#       6 from sklearn.metrics.pairwise import cosine_similarity
# ----> 8 from fastai.text import *
#       9 from inltk.config import LanguageCodes
#      10 from inltk.download_assets import setup_language, verify_language, check_all_languages_identifying_model
#
# File ~\anaconda3\Lib\site-packages\fastai\text\__init__.py:1
# ----> 1 from .. import basics
#       2 from ..basics import *
#       3 from .learner import *
#
# File ~\anaconda3\Lib\site-packages\fastai\basics.py:1
# ----> 1 from .basic_train import *
#       2 from .callback import *
#       3 from .core import *
#
# File ~\anaconda3\Lib\site-packages\fastai\basic_train.py:2
#       1 "Provides basic training and validation with `Learner`"
# ----> 2 from .torch_core import *
#       3 from .basic_data import *
#       4 from .callback import *
#
# File ~\anaconda3\Lib\site-packages\fastai\torch_core.py:2
#       1 "Utility functions to help deal with tensors"
# ----> 2 from .imports.torch import *
#       3 from .core import *
#       4 from collections import OrderedDict
#
# File ~\anaconda3\Lib\site-packages\fastai\imports\__init__.py:1
# ----> 1 from .core import *
#       2 from .torch import *
#
# File ~\anaconda3\Lib\site-packages\fastai\imports\core.py:9
#       6 import html, re, requests, tarfile, numbers, tempfile, bz2
#       8 from abc import abstractmethod, abstractproperty
# ----> 9 from collections import abc,  Counter, defaultdict, Iterable, namedtuple, OrderedDict
#      10 import concurrent
#      11 from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
#
# ImportError: cannot import name 'Iterable' from 'collections' (C:\Users\kargu\anaconda3\Lib\collections\__init__.py)
